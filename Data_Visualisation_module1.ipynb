# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(10000)
plt.hist(x, 100)
plt.title("Normal distribution $\mu=0, \sigma=1$")
plt.savefig("matplotlib_histogram.png")
plt.show()

# %%
plt.plot(5, 4, 'o')
plt.title("Plotting Example")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("world_population_data.csv")
df.head(10)
# Out:
#                    Data Source World Development Indicators  \
# 0                          NaN                          NaN
# 1            Last Updated Date                    9/19/2023
# 2                          NaN                          NaN
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
# 8                       Angola                          AGO
# 9                      Albania                          ALB
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# ...

# %%
df.drop(['Unnamed: 2','Unnamed: 3','World Development Indicators',], axis=1, inplace=True)
df.head(10)
# Out:
#                    Data Source   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                          NaN          NaN          NaN          NaN
# 1            Last Updated Date          NaN          NaN          NaN
# 2                          NaN          NaN          NaN          NaN
# 3                 Country Name       1960.0       1961.0       1962.0
# 4                        Aruba      54608.0      55811.0      56682.0
# 5  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 6                  Afghanistan    8622466.0    8790140.0    8969047.0
# 7   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 8                       Angola    5357195.0    5441333.0    5521400.0
# 9                      Albania    1608800.0    1659800.0    1711319.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
df.drop([0,1,2], axis=0, inplace=True)
df.head(10)
# Out:
#                     Data Source   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 3                  Country Name       1960.0       1961.0       1962.0
# 4                         Aruba      54608.0      55811.0      56682.0
# 5   Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 6                   Afghanistan    8622466.0    8790140.0    8969047.0
# 7    Africa Western and Central   97256290.0   99314028.0  101445032.0
# 8                        Angola    5357195.0    5441333.0    5521400.0
# 9                       Albania    1608800.0    1659800.0    1711319.0
# 10                      Andorra       9443.0      10216.0      11014.0
# 11                   Arab World   93359407.0   95760348.0   98268683.0
# 12         United Arab Emirates     133426.0     140984.0     148877.0
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 3        1963.0       1964.0       1965.0       1966.0       1967.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1:51 ,3].plot( kind='line', title='Line Plot Example')
plt.xlabel('Customer-ID')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1:51 ,3].plot( kind='area', title='Area Example')
plt.xlabel('Customer-ID')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1: ,3].plot( kind='hist', title='Histogram Example')
plt.xlabel('Customer-ID')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1:11, 3].plot( kind='bar',title="Bar Graph")
plt.xlabel('Customer-ID')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1:11, 3:5].plot( kind='bar',title="Bar Graph 2.0 ")
plt.xlabel('Customer-ID')
plt.ylabel("Spending Score (1-100)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.iloc[1:11, 4 ].plot( kind='pie',title="Pie Chart")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("Mall_Customers_data.csv")
df.plot( kind='scatter',title="Scatter Plot",x='Annual Income (k$)',y="Spending Score (1-100)")
plt.xlabel('Annual Income (k$)')
plt.ylabel("Spending Score (1-100)")
plt.show()
